# %% [markdown]
# <a href="https://colab.research.google.com/github/Heity94/TWSM_Lab/blob/main/Project/Notebooks/PH_NER_FineTune_ST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declare whether you are on Colab or local
colab = True

# %%
if colab==True:
  
  #Mount drive
  from google.colab import drive
  drive.mount('/content/drive')

  #install required packages
  # !pip install -U sentence-transformers -q
# Out:
# Mounted at /content/drive
#      |████████████████████████████████| 85 kB 3.9 MB/s
#      |████████████████████████████████| 4.4 MB 17.0 MB/s
#      |████████████████████████████████| 1.2 MB 63.1 MB/s
#      |████████████████████████████████| 101 kB 13.2 MB/s
#      |████████████████████████████████| 596 kB 74.8 MB/s
#      |████████████████████████████████| 6.6 MB 55.4 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
#set path to data in Google Drive
data_path = "/content/drive/MyDrive/2022_Analytics Lab Student Projects/Data/All Topics"
data_path_group = data_path[:-10]+"Topic 1/Data_Team1/" # create new data path to access files created by Team1

# %%
# Import sentence_transformers 
from sentence_transformers import SentenceTransformer, util, InputExample, losses, evaluation
from torch.utils.data import DataLoader
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator, BinaryClassificationEvaluator, TripletEvaluator, LabelAccuracyEvaluator

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from datetime import datetime

# %% [markdown]
# ### Load pretrained sentence transformer model

# %%
model_name = "all-MiniLM-L6-v2"

# %%
# Load a pre-trained model
model = SentenceTransformer(model_name)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# # Fine tuning of pretrained model

# %% [markdown]
# ## Synonyms dataset

# %% [markdown]
# ### Load data

# %%
syn_ont_train = pd.read_csv(data_path_group+"NER/Synonym_Dataset/NER_ontology_train_df_syn.csv", index_col=0)
syn_ont_val = pd.read_csv(data_path_group+"NER/Synonym_Dataset/NER_ontology_val_df_syn.csv", index_col=0)
syn_ont_test= pd.read_csv(data_path_group+"NER/Synonym_Dataset/NER_ontology_test_df_syn.csv", index_col=0)

# %%
syn_ont_train.head(3)
# Out:
#                         entity_id                category              label  \
# 533794             smart contract  domain specific entity         TECHNOLOGY
# 280854  energy information system  domain specific entity         TECHNOLOGY
# 361291          archival research         research method  COLLECTION_METHOD
#
#                                      synonym  is_synonym
# 533794        intelligent process automation           0
# 280854                       energy software           1
# 361291  governmental and governmental record           1

# %%
# Only to test if everything is working
#syn_ont_train = syn_ont_train.iloc[:10_000].copy()

# %% [markdown]
# ### Create sample sets for training/evaluation

# %%
syn_train_samples = []
for index, row in syn_ont_train.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['synonym']], label=float(row['is_synonym']))
  syn_train_samples.append(inp_example)

# %%
syn_evaluation_samples = []
for index, row in syn_ont_val.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['synonym']], label=float(row['is_synonym']))
  syn_evaluation_samples.append(inp_example)

# %%
syn_test_samples = []
for index, row in syn_ont_test.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['synonym']], label=float(row['is_synonym']))
  syn_test_samples.append(inp_example)

# %% [markdown]
# ### Baseline score of pretrained model without finetuning

# %%
# Instantiate Binary Classification evaluator for test set
test_evaluator = BinaryClassificationEvaluator.from_input_examples(syn_test_samples, name='NER-syn-test', show_progress_bar=True,)

# %%
# For the evaluation of the baseline model I had to create this folder manually in Drive first, otherwise it throws an error
model_name_baseline = "all-MiniLM-L6-v2_baseline"
output_path_baseline = data_path_group+"NER/Training_results/"+model_name_baseline+"-Syn"

# %%
# Evluate performance on test set
test_result_baseline = test_evaluator(model, output_path=output_path_baseline)
# Out:
# Batches:   0%|          | 0/163 [00:00<?, ?it/s]

# %%
print(test_result_baseline)
# Out:
# 0.9078516208024627

# %% [markdown]
# Without any fine tuning on the ontology the model classifies 90% of the examples correctly. After finetuning this score should thus be higher than 90%.

# %% [markdown]
# ### Fine tuning the pre trained model

# %%
output_path_syn = data_path_group+"NER/Training_results/"+model_name+'-Syn-'+datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
syn_train_dataloader = DataLoader(syn_train_samples, shuffle=True, batch_size=64)
syn_train_loss = losses.CosineSimilarityLoss(model=model)

# %%
num_epochs = 1
warmup_steps = float(np.ceil(len(syn_train_dataloader) * num_epochs * 0.01)) #1% of train data for warm-up

# %%
evaluator = BinaryClassificationEvaluator.from_input_examples(syn_evaluation_samples)

# %%
adapted_model_syn = SentenceTransformer(model_name)

adapted_model_syn.fit(train_objectives=[(syn_train_dataloader, syn_train_loss)], 
          epochs=num_epochs, 
          warmup_steps=warmup_steps, 
          evaluator=evaluator, 
          evaluation_steps=5000, 
          output_path=output_path_syn)
# Out:
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/8825 [00:00<?, ?it/s]

# %%
# Evluate performance on test set
test_result = test_evaluator(adapted_model_syn, output_path=output_path_syn)
# Out:
# Batches:   0%|          | 0/163 [00:00<?, ?it/s]

# %%
print(test_result)
# Out:
# 0.9986310212959735

# %% [markdown]
# Training the model for one epoch on the complete training dataset improved the accuracy by far. Now the accuracy on the test set is very close to 100%.
#
# We will see how the performance of this model is regarding the real task, to find new entities in the ontology.
#
# If the performance is worse than the pretrained (vanilla) model, we might need to check on how to prevent overfitting, using a smaller learning rate or early stopping (even though with only one epoch of training we would not be able to stop earlier anyhow ...)

# %% [markdown]
# ## Triplets dataset

# %% [markdown]
# ### Load data

# %%
trip_train = pd.read_csv(data_path_group+"NER/Triplets_Dataset/NER_ontology_train_triplets.csv", index_col=0)
trip_val = pd.read_csv(data_path_group+"NER/Triplets_Dataset/NER_ontology_val_triplets.csv", index_col=0)
trip_test = pd.read_csv(data_path_group+"NER/Triplets_Dataset/NER_ontology_test_triplets.csv", index_col=0)

# %%
trip_train.head(3)
# Out:
#                              entity_id  \
# 0                               survey
# 1  computer supported cooperative work
# 2                             IT skill
#
#                                     positive_example  \
# 0  consumer based standardized questionnaire appr...
# 1                applications enabled collaborations
# 2                  competencies for digital employee
#
#                                     negative_example
# 0                              biometric measurement
# 1  Personal Information Protection and Electronic...
# 2                                        floppy disk

# %%
trip_train.shape
# Out:
# (24205, 3)

# %% [markdown]
# ### Create sample sets for training/evaluation

# %%
trip_train_samples = []
for index, row in trip_train.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['positive_example'], row['negative_example']]) 
  trip_train_samples.append(inp_example)

# %%
trip_evaluation_samples = []
for index, row in trip_val.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['positive_example'], row['negative_example']]) 
  trip_evaluation_samples.append(inp_example)

# %%
trip_test_samples = []
for index, row in trip_test.iterrows():
  inp_example = InputExample(texts=[row['entity_id'], row['positive_example'], row['negative_example']]) 
  trip_test_samples.append(inp_example)

# %% [markdown]
# ### Baseline score of pretrained model without finetuning

# %%
# Instantiate Triplet Evaluator evaluator for test set
test_evaluator_trip = TripletEvaluator.from_input_examples(trip_test_samples, main_distance_function=0, name='NER-trip-test', show_progress_bar=True,)

# %%
# For the evaluation of the baseline model I had to create this folder manually in Drive first, otherwise it throws an error
model_name_baseline = "all-MiniLM-L6-v2_baseline"
output_path_baseline_trip = data_path_group+"NER/Training_results/"+model_name_baseline+"-Trip"

# %%
# Evluate performance on test set
test_result_baseline_trip = test_evaluator_trip(model, output_path=output_path_baseline_trip)
# Out:
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
print(test_result_baseline_trip)
# Out:
# 0.9529914529914529

# %% [markdown]
# Without any fine tuning on the ontology the cosine similarity between the anchor and the positive example is in 95% of the examples closer than the cosine similarity between the anchor and the negative example. After finetuning this score should thus be higher than 95%.

# %% [markdown]
# ### Fine tuning the pre trained model

# %%
output_path_trip = data_path_group+"NER/Training_results/"+model_name+'-Trip-'+datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
trip_train_dataloader = DataLoader(trip_train_samples, shuffle=True, batch_size=32)
trip_train_loss = losses.TripletLoss(model=model)

# %%
num_epochs = 1
warmup_steps = float(np.ceil(len(trip_train_dataloader) * num_epochs * 0.01)) #10% of train data for warm-up

# %%
evaluator_trip = TripletEvaluator.from_input_examples(trip_evaluation_samples, main_distance_function=0)

# %%
adapted_model_trip = SentenceTransformer(model_name)

adapted_model_trip.fit(train_objectives=[(trip_train_dataloader, trip_train_loss)], 
          epochs=num_epochs, 
          warmup_steps=warmup_steps, 
          evaluator=evaluator_trip, 
          evaluation_steps=100, 
          output_path=output_path_trip)
# Out:
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/757 [00:00<?, ?it/s]

# %%
# Evluate performance on test set
test_result_trip = test_evaluator_trip(adapted_model_trip, output_path=output_path_trip)
# Out:
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
print(test_result_trip)
# Out:
# 0.8547008547008547

# %% [markdown]
# So after training on the triplets the model performance decreases, which means we overfitted on the train set. Thus we have to reduce overfitting by decreasing the learning rate and/or reduce the number of epochs.
