# %% [markdown]
# <a href="https://colab.research.google.com/github/Heity94/TWSM_Lab/blob/main/Project/Notebooks/SpacyNER_Ontology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declare whether you are on Colab or local
colab = True

# %%
if colab==True:
  
  #Mount drive
  from google.colab import drive
  drive.mount('/content/drive')

  #set path to data in Google Drive
  data_path = "/content/drive/MyDrive/TWSM/Project"

  #install required packages
  # !pip install duckdb
  # !pip install -U sentence-transformers
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 13.9 MB 5.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 79 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 30.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 63.1 MB/s
# ...
#      |████████████████████████████████| 86 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 64.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 72.5 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=e5cf5ace26230f1931b65d591daac7bc1910df330710617c14257a6e09495d6f
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# ...

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb
import sqlalchemy

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
sentences = pd.read_csv(data_path+"/sentences.csv")
sentences.head()
# Out:
#    article_id sentence_id para_id  \
# 0           1       1_0_1     1_0
# 1           1       1_1_2     1_0
# 2           1      1_2_22     1_0
# 3           1     1_22_23     1_1
# 4           1     1_23_24     1_1
#
#                                             sentence  section_nr  \
# 0                                                              0
# 1                                    START_TITLE_TAG           0
# 2  Examining interdependence between product user...           0
# 3                                 START_ABSTRACT_TAG           0
# 4                                                              0
#
#   last_section_title last_subsection_title sentence_type references  \
# 0                NaN                   NaN         EMPTY         []
# 1                NaN                   NaN           TAG         []
# 2                NaN                   NaN     PARAGRAPH         []
# 3                NaN                   NaN           TAG         []
# ...

# %%
con = duckdb.connect(database=data_path+'/isrecon.duckdb', read_only=False)

# %%
# Import the table "entities" as a df
entities = con.execute("SELECT * FROM entities").fetchdf()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-96b61597dfee> in <module>()
#       1 # Import the table "entities" as a df
# ----> 2 entities = con.execute("SELECT * FROM entities").fetchdf()
#
# RuntimeError: Catalog Error: Table with name entities does not exist!
# LINE 1: SELECT * FROM entities
#                       ^

# %%
# Join the the 2 dataframes on sentence_id to get the word and the corresponding entity 


# Create a JSON file 


# Split them into train and test data

# %%
# Converting the JSON files to SpaCy binary file

# !python -m spacy convert drive/MyDrive/TWSM/Project/train.json ./ -t spacy
# !python -m spacy convert drive/MyDrive/TWSM/Project/test.json ./ -t spacy

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_trf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.2 MB 17.1 MB/s
# ...
#      |████████████████████████████████| 660 kB 68.3 MB/s
# ...
#      |████████████████████████████████| 181 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 56.2 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 457 kB 69.5 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.4 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
# ...

# %%
# Install the cuda

# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2
# Out:
# --2022-06-13 18:17:12--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.39.144
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 [following]
# --2022-06-13 18:17:13--  https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Install pytorch

# !pip install torch==1.7.1+cu92 torchvision==0.8.2+cu92 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 577.3 MB 3.4 kB/s
# ...
#      |████████████████████████████████| 12.5 MB 62.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 33.2 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.11.0+cu113
#     Uninstalling torchaudio-0.11.0+cu113:
#       Successfully uninstalled torchaudio-0.11.0+cu113
# ...

# %%
# Install spacy and transformer packages

# !export CUDA_PATH="/usr/local/cuda-9.2"
# !pip install -U spacy[cuda92,transformers]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55.0 MB 159 kB/s
# ...

# %%
# Install cupy

# !pip install cupy

# Set the cuda path

# !export LD_LIBRARY_PATH=$CUDA_PATH/lib64:$LD_LIBRARY_PATH
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.7 MB 35.9 MB/s
# ...
#   ERROR: Failed building wheel for cupy
#   Running setup.py clean for cupy
#   ERROR: Failed cleaning build dir for cupy
# Failed to build cupy
# ...
#     Running setup.py install for cupy ... error
# ...

# %%
# !python -m spacy init fill-config drive/MyDrive/TWSM/Project/config.cfg drive/MyDrive/TWSM/Project/config_spacy.cfg

# %%
# Training the BERT

# !python -m spacy train -g 0 drive/MyDrive/TWSM/Project/config.cfg — output ./

# %%
# Loading the saved model

nlp = spacy.load(“./model-best”)
